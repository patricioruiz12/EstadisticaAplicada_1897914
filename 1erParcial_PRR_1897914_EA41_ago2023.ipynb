# %% [markdown]
# ## Estadística Aplicada
# Parcial #1
#
# Patricio Ruiz Rodriguez 1897914
#
# Grupo 41

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Ejercicio 1

# %%
datos=pd.read_csv('https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/peliculas.csv')

# %%
datos
# Out:
#                  title                                        description  \
# 0     Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1       Ace Goldfinger  A Astounding Epistle of a Database Administrat...
# 2     Adaptation Holes  A Astounding Reflection of a Lumberjack And a ...
# 3     Affair Prejudice  A Fanciful Documentary of a Frisbee And a Lumb...
# 4          African Egg  A Fast-Paced Documentary of a Pastry Chef And ...
# ..                 ...                                                ...
# 995     Young Language  A Unbelieveable Yarn of a Boat And a Database ...
# 996         Youth Kick  A Touching Drama of a Teacher And a Cat who mu...
# 997       Zhivago Core  A Fateful Yarn of a Composer And a Man who mus...
# 998  Zoolander Fiction  A Fateful Reflection of a Waitress And a Boat ...
# 999          Zorro Ark  A Intrepid Panorama of a Mad Scientist And a B...
#
#      release_year  rental_rate  length rating  \
# ...

# %% [markdown]
# a) Cuantas  películas  hay,  cuantos  géneros,  y  cuanto  duran  en  promedio  las películas

# %%
peliculas = datos['title'].count()

# %%
categorias = datos['category'].value_counts()
categorias = categorias.count()

# %%
duracion = np.mean(datos['length'])

# %%
print(f'Películas: {peliculas}')
print(f'Géneros: {categorias}')
print(f'Promedio: {duracion}')
# Out:
# Películas: 1000
# Géneros: 16
# Promedio: 115.272

# %% [markdown]
# b) Crea  un  dataframe  llamado películas_dormir  con  las  películas  que  tienen  una duración superior a 2 horas y sean documentales

# %%
datos['length_hrs'] = datos['length']/60
datos
# Out:
#                  title                                        description  \
# 0     Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1       Ace Goldfinger  A Astounding Epistle of a Database Administrat...
# 2     Adaptation Holes  A Astounding Reflection of a Lumberjack And a ...
# 3     Affair Prejudice  A Fanciful Documentary of a Frisbee And a Lumb...
# 4          African Egg  A Fast-Paced Documentary of a Pastry Chef And ...
# ..                 ...                                                ...
# 995     Young Language  A Unbelieveable Yarn of a Boat And a Database ...
# 996         Youth Kick  A Touching Drama of a Teacher And a Cat who mu...
# 997       Zhivago Core  A Fateful Yarn of a Composer And a Man who mus...
# 998  Zoolander Fiction  A Fateful Reflection of a Waitress And a Boat ...
# 999          Zorro Ark  A Intrepid Panorama of a Mad Scientist And a B...
#
#      release_year  rental_rate  length rating  \
# ...

# %%
peliculas_dormir = datos.query('category=="Documentary" & length_hrs > 2.0')
peliculas_dormir
# Out:
#                      title                                        description  \
# 39        Army Flintstones  A Boring Saga of a Database Administrator And ...
# 57     Beach Heartbreakers  A Fateful Display of a Womanizer And a Mad Sci...
# 128             Cause Date  A Taut Tale of a Explorer And a Pastry Chef wh...
# 141   Chicken Hellfighters  A Emotional Drama of a Dog And a Explorer who ...
# 155          Clerks Angels  A Thrilling Display of a Sumo Wrestler And a G...
# 205          Dancing Fever  A Stunning Story of a Explorer And a Forensic ...
# 247             Dozen Lion  A Taut Drama of a Cat And a Girl who must Defe...
# 260      Duffel Apocalypse  A Emotional Display of a Boat And a Explorer w...
# 440           Hunter Alter  A Emotional Drama of a Mad Cow And a Boat who ...
# 456     Independence Hotel  A Thrilling Tale of a Technical Writer And a B...
# 543           Madison Trap  A Awe-Inspiring Reflection of a Monkey And a D...
# ...

# %% [markdown]
# c) Contar cuántas películas de cada género existen

# %%
datos['category'].value_counts()
# Out:
# category
# Foreign        73
# Sports         73
# Family         69
# Documentary    68
# Animation      66
# Action         64
# New            63
# Sci-Fi         61
# Drama          61
# Games          61
# Children       60
# Comedy         58
# Classics       57
# Horror         56
# Travel         56
# Music          51
# Name: count, dtype: int64

# %% [markdown]
# d) Calcular la duración promedio de las películas de cada género.

# %%
dur_gen = datos.groupby('category')['length_hrs'].mean()
dur_gen
# Out:
# category
# Action         1.860156
# Animation      1.850253
# Children       1.830000
# Classics       1.861111
# Comedy         1.930460
# Documentary    1.812500
# Drama          1.998087
# Family         1.913043
# Foreign        2.028311
# Games          2.130601
# Horror         1.874702
# Music          1.894118
# New            1.852116
# Sci-Fi         1.803279
# Sports         2.125114
# Travel         1.889583
# Name: length_hrs, dtype: float64

# %% [markdown]
# e) Crear una nueva columna que indique si una película es "Corta" (duración menor a 1.5 horas), "Normal" (entre 1.5 y 2.5 horas) o "Larga" (mayor a 2.5 horas).

# %%
condiciones = [datos['length_hrs']<1.5,
               datos['length_hrs']<=2.5,
               datos['length_hrs']>2.5]
valor_condicion = ['Corta', 'Normal', 'Larga']
datos['length_class'] = np.select(condiciones, valor_condicion, default='Invalid')
datos
# Out:
#                  title                                        description  \
# 0     Academy Dinosaur  A Epic Drama of a Feminist And a Mad Scientist...
# 1       Ace Goldfinger  A Astounding Epistle of a Database Administrat...
# 2     Adaptation Holes  A Astounding Reflection of a Lumberjack And a ...
# 3     Affair Prejudice  A Fanciful Documentary of a Frisbee And a Lumb...
# 4          African Egg  A Fast-Paced Documentary of a Pastry Chef And ...
# ..                 ...                                                ...
# 995     Young Language  A Unbelieveable Yarn of a Boat And a Database ...
# 996         Youth Kick  A Touching Drama of a Teacher And a Cat who mu...
# 997       Zhivago Core  A Fateful Yarn of a Composer And a Man who mus...
# 998  Zoolander Fiction  A Fateful Reflection of a Waitress And a Boat ...
# 999          Zorro Ark  A Intrepid Panorama of a Mad Scientist And a B...
#
#      release_year  rental_rate  length rating  \
# ...

# %% [markdown]
# Ejercicio 2

# %%
poblacion_Asgard = pd.read_csv('https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/poblacion_Asgard.csv')
poblacion_Asgard
# Out:
#       País     Estado      Municipio  Población
# 0   Asgard    Pandora   Reino Tierra     377896
# 1   Asgard   Alderaan  Fuente Dorada      49984
# 2   Asgard    Genosha      El Carmen     303918
# 3   Asgard      Naboo         Omashu     265712
# 4   Asgard     Mordor      Don Bosco     121151
# ..     ...        ...            ...        ...
# 85  Asgard     Gotham    Mar violeta      44585
# 86  Asgard  Mandalore   Mar amarillo     372369
# 87  Asgard   Mustafar       Mar Azul      65044
# 88  Asgard   Atlantis   Mar amarillo     961061
# 89  Asgard     Narnia   Mar amarillo     443296
#
# [90 rows x 4 columns]

# %% [markdown]
# a) Ordena la base alfabéticamente por estado y por municipio

# %%
poblacion_Asgard.sort_values(by= ["Estado","Municipio"])
# Out:
#       País    Estado       Municipio  Población
# 16  Asgard  Alderaan     Ciudad Jedi     130312
# 1   Asgard  Alderaan   Fuente Dorada      49984
# 31  Asgard  Alderaan        Luz azul     914910
# 76  Asgard  Alderaan          Madero     774290
# 46  Asgard  Alderaan      San Isidro     159338
# ..     ...       ...             ...        ...
# 8   Asgard     Yaven       El Bosque     649663
# 83  Asgard     Yaven      Green Flag     380989
# 68  Asgard     Yaven     Santa María     111687
# 53  Asgard     Yaven     Villa Wendy     646914
# 38  Asgard     Yaven  Villa amarilla     274109
#
# [90 rows x 4 columns]

# %% [markdown]
# b) Cuantos  estados  hay,  cuantos  municipios  hay  en  cada  estado  y  cuantos municipios hay en total.

# %%
estados = poblacion_Asgard['Estado'].value_counts().count()
estados
# Out:
# 15

# %%
poblacion_Asgard['Estado'].value_counts()
# Out:
# Estado
# Pandora      6
# Alderaan     6
# Genosha      6
# Naboo        6
# Mordor       6
# Tatooine     6
# Sokovia      6
# Wakanda      6
# Yaven        6
# Endor        6
# Gotham       6
# Mandalore    6
# Mustafar     6
# Atlantis     6
# Narnia       6
# Name: count, dtype: int64

# %%
municipios = poblacion_Asgard['Municipio'].value_counts().count()
municipios
# Out:
# 59

# %% [markdown]
# c) Cuanta población tiene el país en total y cuanta población tiene cada estado

# %%
Poblacion_total = np.sum(poblacion_Asgard['Población'])
Poblacion_total
# Out:
# 43114719

# %%
pobxestado = poblacion_Asgard.groupby('Estado')['Población'].sum()
pobxestado
# Out:
# Estado
# Alderaan     2283452
# Atlantis     3779656
# Endor        2427956
# Genosha      2871584
# Gotham       3204304
# Mandalore    2044164
# Mordor       3627119
# Mustafar     2183880
# Naboo        1602111
# Narnia       2961407
# Pandora      2959272
# Sokovia      4722224
# Tatooine     2770055
# Wakanda      2905562
# Yaven        2771973
# Name: Población, dtype: int64

# %% [markdown]
# d) Calcula la mediana de la población de los municipios, y clasifícalos, aquellos por arriba de la mediana deben llamarse “muy poblados” y aquellos debajo de la mediana “poco poblados”

# %%
med_mun = poblacion_Asgard['Población'].median()

# %%
poblacion_Asgard['clas_municipio'] = np.where(poblacion_Asgard['Población']< med_mun, 'poco poblado' , 'muy poblado')
poblacion_Asgard
# Out:
#       País     Estado      Municipio  Población clas_municipio
# 0   Asgard    Pandora   Reino Tierra     377896   poco poblado
# 1   Asgard   Alderaan  Fuente Dorada      49984   poco poblado
# 2   Asgard    Genosha      El Carmen     303918   poco poblado
# 3   Asgard      Naboo         Omashu     265712   poco poblado
# 4   Asgard     Mordor      Don Bosco     121151   poco poblado
# ..     ...        ...            ...        ...            ...
# 85  Asgard     Gotham    Mar violeta      44585   poco poblado
# 86  Asgard  Mandalore   Mar amarillo     372369   poco poblado
# 87  Asgard   Mustafar       Mar Azul      65044   poco poblado
# 88  Asgard   Atlantis   Mar amarillo     961061    muy poblado
# 89  Asgard     Narnia   Mar amarillo     443296   poco poblado
#
# [90 rows x 5 columns]

# %% [markdown]
# e) Encuentra  los  5  municipios  mas  poblados  y  los  cinco  municipios  menos poblados del país

# %%
mp = poblacion_Asgard.sort_values(by= ["Población","Municipio"])

# %%
mp['Municipio'].head()
# Out:
# 17    Ciudad Jedi
# 14       Luz roja
# 39     Villa rosa
# 26    Shelbyville
# 85    Mar violeta
# Name: Municipio, dtype: object

# %%
mp['Municipio'].tail()
# Out:
# 79      Yellow town
# 74    Gral Escobedo
# 6          La Unión
# 27      Villa Norte
# 34         Madripur
# Name: Municipio, dtype: object

# %% [markdown]
# f) El municipio más poblado de cada estado

# %%
mas_pob = poblacion_Asgard.groupby('Población')['Municipio'].max()
mas_pob
# Out:
# Población
# 13666       Ciudad Jedi
# 14986          Luz roja
# 25538        Villa rosa
# 31535       Shelbyville
# 44585       Mar violeta
#               ...
# 974324      Yellow town
# 974548    Gral Escobedo
# 986067         La Unión
# 997107      Villa Norte
# 998079         Madripur
# Name: Municipio, Length: 90, dtype: object

# %% [markdown]
# Ejercicio 3

# %% [markdown]
# a) Los 15 municipios más poblados de Asgard

# %%
a = poblacion_Asgard.groupby('Población')['Municipio']
a = a.value_counts()
a = a.sort_values(ascending=False)
a.plot.bar()
# Out:
# <Axes: xlabel='Población,Municipio'>

# %% [markdown]
# b) Cuantas peliculas hay de cada género

# %%
p = datos['category'].value_counts()
p = p.sort_values(ascending=False)
plt.title('Peliculas por género')
plt.xlabel('Género')
plt.ylabel('# de pleículas')
p.plot.bar()
